# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import open3d as o3d
from tqdm import tqdm
from torch.utils.data import DataLoader
from learning3d.models import PPFNet
from learning3d.data_utils import ClassificationData, ModelNet40Data

# Cihaz ayarı
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Veri setini yükle (4096 nokta)
num_points = 4096
train_dataset = ClassificationData(data_class=ModelNet40Data(train=True, num_points=num_points))
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, num_workers=2)
test_dataset = ClassificationData(data_class=ModelNet40Data(train=False, num_points=num_points))
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False, num_workers=2)

def compute_normals_single(points_single):
    """Open3D kullanarak yüzey normallerini hesaplar."""
    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(points_single.astype(np.float64))
    pcd.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
    return np.asarray(pcd.normals)

def augment(points):
    noise = torch.randn_like(points) * 0.02
    angle = torch.rand(1) * 2 * torch.pi
    rotation_matrix = torch.tensor([
        [torch.cos(angle), -torch.sin(angle), 0],
        [torch.sin(angle), torch.cos(angle), 0],
        [0, 0, 1]
    ], dtype=torch.float32).to(points.device)
    return torch.matmul(points, rotation_matrix) + noise

# Model Tanımı
class PPFNetClassifier(nn.Module):
    def __init__(self, num_classes=40, embedding_dim=128):
        super(PPFNetClassifier, self).__init__()
        self.encoder = PPFNet(features=['ppf', 'dxyz', 'xyz'], emb_dims=embedding_dim, radius=0.3, num_neighbors=64)
        self.fc = nn.Sequential(
            nn.Linear(embedding_dim, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(negative_slope=0.1),
            nn.Dropout(0.4),

            nn.Linear(512, 1024),
            nn.BatchNorm1d(1024),
            nn.LeakyReLU(negative_slope=0.1),
            nn.Dropout(0.4),

            nn.Linear(1024, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(negative_slope=0.1),
            nn.Dropout(0.3),

            nn.Linear(512, num_classes)
        )
        
    def forward(self, points, normals):
        features = self.encoder(points, normals)
        global_embedding = torch.max(features, dim=1)[0]
        return self.fc(global_embedding)

# Model, optimizer, loss fonksiyonu
model = PPFNetClassifier(num_classes=40, embedding_dim=128).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3, betas=(0.9, 0.999), weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=30, eta_min=1e-6)

num_epochs = 30
train_losses, val_losses, train_accs, val_accs = [], [], [], []

for epoch in range(num_epochs):
    model.train()
    epoch_loss, correct, total = 0, 0, 0
    for i, data in enumerate(tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}")):
        points, labels = data
        points = (points - points.mean(dim=1, keepdim=True)) / torch.max(torch.norm(points, dim=-1, keepdim=True))
        points = points.to(device, dtype=torch.float32)
        labels = labels.squeeze().to(device)
        
        normals = torch.tensor(np.stack([compute_normals_single(p.cpu().numpy()) for p in points.cpu()], axis=0), dtype=torch.float32).to(device)
        outputs = model(points, normals)
        
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        correct += (outputs.argmax(1) == labels).sum().item()
        total += labels.size(0)
    
    train_losses.append(epoch_loss / len(train_loader))
    train_accs.append(100 * correct / total)
    
    # Validation
    model.eval()
    val_loss, correct, total = 0, 0, 0
    with torch.no_grad():
        for data in test_loader:
            points, labels = data
            points = points.to(device, dtype=torch.float32)
            labels = labels.squeeze().to(device)
            
            normals = torch.tensor(np.stack([compute_normals_single(p.cpu().numpy()) for p in points.cpu()], axis=0), dtype=torch.float32).to(device)
            outputs = model(points, normals)
            
            val_loss += criterion(outputs, labels).item()
            correct += (outputs.argmax(1) == labels).sum().item()
            total += labels.size(0)
    
    val_losses.append(val_loss / len(test_loader))
    val_accs.append(100 * correct / total)
    
    # Modeli kaydet
    torch.save(model.encoder.state_dict(), f"ppfnet_encoder_epoch{epoch+1}.pth")
    torch.save(model.fc.state_dict(), f"ppfnet_classifier_epoch{epoch+1}.pth")
    scheduler.step()
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_losses[-1]:.4f}, Train Acc: {train_accs[-1]:.2f}%, Val Loss: {val_losses[-1]:.4f}, Val Acc: {val_accs[-1]:.2f}%")

# Sonuçları görselleştir
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_losses, label='Train Loss')
plt.plot(range(1, num_epochs + 1), val_losses, label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss vs. Epochs')

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_accs, label='Train Accuracy')
plt.plot(range(1, num_epochs + 1), val_accs, label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.title('Accuracy vs. Epochs')

plt.show()
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# Using device: cuda
# Epoch 1/30: 100%|███████████████████████████| 1230/1230 [05:08<00:00,  3.98it/s]
# Epoch [1/30], Train Loss: 1.8443, Train Acc: 49.20%, Val Loss: 2.1555, Val Acc: 41.00%
# Epoch 2/30: 100%|███████████████████████████| 1230/1230 [05:08<00:00,  3.99it/s]
# Epoch [2/30], Train Loss: 1.2887, Train Acc: 62.39%, Val Loss: 1.4829, Val Acc: 56.00%
# Epoch 3/30: 100%|███████████████████████████| 1230/1230 [05:08<00:00,  3.99it/s]
# Epoch [3/30], Train Loss: 1.1084, Train Acc: 66.92%, Val Loss: 2.6500, Val Acc: 37.24%
# Epoch 4/30: 100%|███████████████████████████| 1230/1230 [05:08<00:00,  3.99it/s]
# Epoch [4/30], Train Loss: 1.0088, Train Acc: 69.71%, Val Loss: 1.1164, Val Acc: 65.28%
# Epoch 5/30: 100%|███████████████████████████| 1230/1230 [05:08<00:00,  3.99it/s]
# Epoch [5/30], Train Loss: 0.9284, Train Acc: 71.64%, Val Loss: 0.9427, Val Acc: 69.69%
# Epoch 6/30: 100%|███████████████████████████| 1230/1230 [05:08<00:00,  3.99it/s]
# Epoch [6/30], Train Loss: 0.8784, Train Acc: 73.50%, Val Loss: 0.7573, Val Acc: 75.00%
# Epoch 7/30: 100%|███████████████████████████| 1230/1230 [05:08<00:00,  3.99it/s]
# Epoch [7/30], Train Loss: 0.7962, Train Acc: 75.71%, Val Loss: 0.8448, Val Acc: 73.95%
# Epoch 8/30: 100%|███████████████████████████| 1230/1230 [05:08<00:00,  3.99it/s]
# Epoch [8/30], Train Loss: 0.7514, Train Acc: 76.64%, Val Loss: 0.8422, Val Acc: 73.91%
# Epoch 9/30: 100%|███████████████████████████| 1230/1230 [05:08<00:00,  3.99it/s]
# Epoch [9/30], Train Loss: 0.7170, Train Acc: 78.24%, Val Loss: 0.5456, Val Acc: 83.75%
# Epoch 10/30: 100%|██████████████████████████| 1230/1230 [05:09<00:00,  3.98it/s]
# Epoch [10/30], Train Loss: 0.6785, Train Acc: 78.89%, Val Loss: 0.7215, Val Acc: 78.20%
# Epoch 11/30: 100%|██████████████████████████| 1230/1230 [05:10<00:00,  3.97it/s]
# Epoch [11/30], Train Loss: 0.6346, Train Acc: 80.20%, Val Loss: 0.5495, Val Acc: 83.23%
# Epoch 12/30: 100%|██████████████████████████| 1230/1230 [05:12<00:00,  3.93it/s]
# Epoch [12/30], Train Loss: 0.5933, Train Acc: 81.22%, Val Loss: 0.5061, Val Acc: 84.68%
# Epoch 13/30: 100%|██████████████████████████| 1230/1230 [05:14<00:00,  3.92it/s]
# Epoch [13/30], Train Loss: 0.5782, Train Acc: 81.49%, Val Loss: 0.5675, Val Acc: 82.94%
# Epoch 14/30: 100%|██████████████████████████| 1230/1230 [05:08<00:00,  3.99it/s]
# Epoch [14/30], Train Loss: 0.5470, Train Acc: 82.82%, Val Loss: 0.4432, Val Acc: 86.35%
# Epoch 15/30: 100%|██████████████████████████| 1230/1230 [05:08<00:00,  3.99it/s]
# Epoch [15/30], Train Loss: 0.5292, Train Acc: 83.30%, Val Loss: 0.4507, Val Acc: 86.75%
# Epoch 16/30: 100%|██████████████████████████| 1230/1230 [05:08<00:00,  3.99it/s]
# Epoch [16/30], Train Loss: 0.4828, Train Acc: 84.23%, Val Loss: 0.4193, Val Acc: 87.28%
# Epoch 17/30: 100%|██████████████████████████| 1230/1230 [05:08<00:00,  3.99it/s]
# Epoch [17/30], Train Loss: 0.4722, Train Acc: 84.85%, Val Loss: 0.4204, Val Acc: 86.99%
# Epoch 18/30: 100%|██████████████████████████| 1230/1230 [05:08<00:00,  3.99it/s]
# Epoch [18/30], Train Loss: 0.4482, Train Acc: 85.65%, Val Loss: 0.4340, Val Acc: 87.03%
# Epoch 19/30: 100%|██████████████████████████| 1230/1230 [05:08<00:00,  3.99it/s]
# Epoch [19/30], Train Loss: 0.4117, Train Acc: 86.55%, Val Loss: 0.4078, Val Acc: 87.52%
# Epoch 20/30: 100%|██████████████████████████| 1230/1230 [05:06<00:00,  4.01it/s]
# Epoch [20/30], Train Loss: 0.3976, Train Acc: 87.18%, Val Loss: 0.3781, Val Acc: 88.86%
# Epoch 21/30: 100%|██████████████████████████| 1230/1230 [05:06<00:00,  4.01it/s]
# Epoch [21/30], Train Loss: 0.3719, Train Acc: 88.03%, Val Loss: 0.3807, Val Acc: 88.57%
# Epoch 22/30: 100%|██████████████████████████| 1230/1230 [05:06<00:00,  4.01it/s]
# Epoch [22/30], Train Loss: 0.3572, Train Acc: 88.35%, Val Loss: 0.3732, Val Acc: 88.82%
# Epoch 23/30: 100%|██████████████████████████| 1230/1230 [05:06<00:00,  4.01it/s]
# Epoch [23/30], Train Loss: 0.3346, Train Acc: 89.14%, Val Loss: 0.3480, Val Acc: 89.18%
# Epoch 24/30: 100%|██████████████████████████| 1230/1230 [05:06<00:00,  4.01it/s]
# Epoch [24/30], Train Loss: 0.3301, Train Acc: 89.03%, Val Loss: 0.3737, Val Acc: 88.90%
# Epoch 25/30: 100%|██████████████████████████| 1230/1230 [05:06<00:00,  4.01it/s]
# Epoch [25/30], Train Loss: 0.3029, Train Acc: 89.87%, Val Loss: 0.3619, Val Acc: 89.26%
# Epoch 26/30: 100%|██████████████████████████| 1230/1230 [05:06<00:00,  4.01it/s]
# Epoch [26/30], Train Loss: 0.2884, Train Acc: 90.28%, Val Loss: 0.3504, Val Acc: 89.42%
# Epoch 27/30: 100%|██████████████████████████| 1230/1230 [05:06<00:00,  4.01it/s]
# Epoch [27/30], Train Loss: 0.2772, Train Acc: 90.95%, Val Loss: 0.3440, Val Acc: 89.59%
# Epoch 28/30: 100%|██████████████████████████| 1230/1230 [05:06<00:00,  4.01it/s]
# Epoch [28/30], Train Loss: 0.2623, Train Acc: 91.21%, Val Loss: 0.3385, Val Acc: 89.71%
# Epoch 29/30: 100%|██████████████████████████| 1230/1230 [05:06<00:00,  4.01it/s]
# Epoch [29/30], Train Loss: 0.2719, Train Acc: 91.08%, Val Loss: 0.3500, Val Acc: 89.10%
# Epoch 30/30: 100%|██████████████████████████| 1230/1230 [05:06<00:00,  4.01it/s]
# Epoch [30/30], Train Loss: 0.2654, Train Acc: 91.38%, Val Loss: 0.3403, Val Acc: 89.67%

# %%
# Sonuçları görselleştir
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_losses, label='Train Loss')
plt.plot(range(1, num_epochs + 1), val_losses, label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss vs. Epochs')

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_accs, label='Train Accuracy')
plt.plot(range(1, num_epochs + 1), val_accs, label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.title('Accuracy vs. Epochs')

plt.savefig("ppfnet_train.png", dpi=300)
plt.show()
